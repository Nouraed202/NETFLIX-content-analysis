# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nt=pd.read_csv('netflix.csv')

# %%
nt=pd.read_csv('netflix.csv')
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
nt.columns.str.split()
# Out:
# Index([     ['show_id'],         ['type'],        ['title'],     ['director'],
#                ['cast'],      ['country'],   ['date_added'], ['release_year'],
#              ['rating'],     ['duration'],    ['listed_in'],  ['description']],
#       dtype='object')

# %%
nt.drop('Unnamed: 12',axis=1,inplace=True)

# %%
print(nt.isna().sum())
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
nt.fillna('Unknown', inplace=True)
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
nt['date_added']=pd.to_datetime(nt['date_added'],dayfirst=True,errors='ignore')
# Out:
# <ipython-input-44-d317f9ff8a8b>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nt['date_added']=pd.to_datetime(nt['date_added'],dayfirst=True,errors='coerce')

# %%
print(nt['date_added'].isna().sum())
# Out:
# 0

# %%
print(nt.duplicated().sum())
# Out:
# 0

# %%
nt.to_csv('netflix_cleaned.csv',index=False)
